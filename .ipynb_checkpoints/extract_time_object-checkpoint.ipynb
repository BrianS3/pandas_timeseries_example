# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
# %cd /content/drive/My\ Drive//\google colab notebooks/
# Out:
# /content/drive/My Drive/google colab notebooks

# %%
df = pd.read_csv('airlinedelaycauses_DelayedFlights.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Year  Month  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0           0  2008      1  ...       NaN            NaN                NaN
# 1           1  2008      1  ...       NaN            NaN                NaN
# 2           2  2008      1  ...       NaN            NaN                NaN
# 3           4  2008      1  ...       0.0            0.0               32.0
# 4           5  2008      1  ...       NaN            NaN                NaN
#
# [5 rows x 30 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
from datetime import datetime as dt

# %%
import time

# %%
df['DepTime'][0]
# Out:
# 2003.0

# %%
dt.strptime(str(df['DepTime'][0]), "%H%M.%S").time()
# Out:
# datetime.time(20, 3)
